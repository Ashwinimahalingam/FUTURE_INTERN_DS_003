# %% [markdown]
#                                                    🎓Student Feedback Analysis using NLP

# %% [markdown]
# IMPORT LIBRARIES

# %%
import pandas as pd

# %%
df=pd.read_excel("student_feedback.xlsx")
df.head()
# Out:
#    Unnamed: 0  Student ID  Well versed with the subject  \
# 0           0         340                             5
# 1           1         253                             6
# 2           2         680                             7
# 3           3         806                             9
# 4           4         632                             8
#
#    Explains concepts in an understandable way  Use of presentations  \
# 0                                           2                     7
# 1                                           5                     8
# 2                                           7                     6
# 3                                           6                     7
# 4                                          10                     8
#
#    Degree of difficulty of assignments  Solves doubts willingly  \
# 0                                    6                        9
# 1                                    6                        2
# ...

# %%
df.to_csv("student_feedback.csv",index=False)
print("file saved as student_feedback.csv")
# Out:
# file saved as student_feedback.csv

# %%
df_csv=pd.read_csv("student_feedback.csv")
df_csv.head()
# Out:
#    Unnamed: 0  Student ID  Well versed with the subject  \
# 0           0         340                             5
# 1           1         253                             6
# 2           2         680                             7
# 3           3         806                             9
# 4           4         632                             8
#
#    Explains concepts in an understandable way  Use of presentations  \
# 0                                           2                     7
# 1                                           5                     8
# 2                                           7                     6
# 3                                           6                     7
# 4                                          10                     8
#
#    Degree of difficulty of assignments  Solves doubts willingly  \
# 0                                    6                        9
# 1                                    6                        2
# ...

# %%
filename='student_feedback.csv'

# %%
df = pd.read_csv(filename)
df
# Out:
#       Unnamed: 0  Student ID  Well versed with the subject  \
# 0              0         340                             5
# 1              1         253                             6
# 2              2         680                             7
# 3              3         806                             9
# 4              4         632                             8
# ...          ...         ...                           ...
# 996          996          55                             8
# 997          997         913                             5
# 998          998         199                             9
# 999          999         539                            10
# 1000        1000         759                             7
#
#       Explains concepts in an understandable way  Use of presentations  \
# 0                                              2                     7
# 1                                              5                     8
# ...

# %%
df_clean = df.drop(columns=['Unnamed: 0'])

# %%
df_clean
# Out:
#       Student ID  Well versed with the subject  \
# 0            340                             5
# 1            253                             6
# 2            680                             7
# 3            806                             9
# 4            632                             8
# ...          ...                           ...
# 996           55                             8
# 997          913                             5
# 998          199                             9
# 999          539                            10
# 1000         759                             7
#
#       Explains concepts in an understandable way  Use of presentations  \
# 0                                              2                     7
# 1                                              5                     8
# 2                                              7                     6
# 3                                              6                     7
# ...

# %%
missing_values=df_clean.isnull().sum()

# %%
missing_values
# Out:
# Student ID                                              0
# Well versed with the subject                            0
# Explains concepts in an understandable way              0
# Use of presentations                                    0
# Degree of difficulty of assignments                     0
# Solves doubts willingly                                 0
# Structuring of the course                               0
# Provides support for students going above and beyond    0
# Course recommendation based on relevance                0
# dtype: int64

# %%
avg_scores=df_clean.drop(columns=['Student ID']).mean().sort_values(ascending=False)

# %%
avg_scores
# Out:
# Well versed with the subject                            7.497502
# Explains concepts in an understandable way              6.081918
# Use of presentations                                    5.942058
# Provides support for students going above and beyond    5.662338
# Structuring of the course                               5.636364
# Course recommendation based on relevance                5.598402
# Solves doubts willingly                                 5.474525
# Degree of difficulty of assignments                     5.430569
# dtype: float64

# %%
overall_satisfaction=df_clean.drop(columns=['Student ID']).mean(axis=1)

# %%
overall_satisfaction
# Out:
# 0       5.000
# 1       4.875
# 2       4.375
# 3       5.875
# 4       7.500
#         ...
# 996     6.375
# 997     5.125
# 998     4.625
# 999     5.125
# 1000    4.875
# Length: 1001, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,5))
sns.barplot(
    x=avg_scores.values,
    y=avg_scores.index,
    hue=avg_scores.index,
    palette="mako",
    legend=False
)
plt.title("average Ratings per aspect",fontsize=16)
plt.xlabel("Average score")
plt.ylabel("Aspect")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Keep only numeric columns
numeric_df = df.select_dtypes(include=['number'])

# Drop NaN values
numeric_df = numeric_df.dropna()

# Plot heatmap
plt.figure(figsize=(8,6))
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation between numeric features", fontsize=14)
plt.show()

# %%
missing_values,avg_scores.head(),overall_satisfaction.head()
# Out:
# (Student ID                                              0
#  Well versed with the subject                            0
#  Explains concepts in an understandable way              0
#  Use of presentations                                    0
#  Degree of difficulty of assignments                     0
#  Solves doubts willingly                                 0
#  Structuring of the course                               0
#  Provides support for students going above and beyond    0
#  Course recommendation based on relevance                0
#  dtype: int64,
#  Well versed with the subject                            7.497502
#  Explains concepts in an understandable way              6.081918
#  Use of presentations                                    5.942058
#  Provides support for students going above and beyond    5.662338
#  Structuring of the course                               5.636364
#  dtype: float64,
#  0    5.000
#  1    4.875
#  2    4.375
#  3    5.875
#  4    7.500
# ...

# %%
for col in df_clean.drop(columns=['Student ID']).columns:
    plt.figure(figsize=(6,4))
    
    # Boxplot + Violinplot
    sns.violinplot(x=df_clean[col], color='#CBAACB', inner=None, alpha=0.6)
    sns.boxplot(x=df_clean[col], width=0.2, boxprops={'facecolor':'white'}, showfliers=False)

    plt.title(f'Distribution of Ratings: {col}', fontsize=14)
    plt.xlabel("Rating")
    plt.ylabel("Density")
    plt.show()

# %%
top_aspects=avg_scores.head(3)
bottom_aspects=avg_scores.tail(3)
top_aspects
bottom_aspects
# Out:
# Course recommendation based on relevance    5.598402
# Solves doubts willingly                     5.474525
# Degree of difficulty of assignments         5.430569
# dtype: float64

# %%
insights={
    "Top 3 aspects":top_aspects.to_dict(),
    "Bottom 3 aspects":bottom_aspects.to_dict(),
    "Overall Average satisfaction":round(overall_satisfaction.mean(),2),
    "Highest Rating":round(avg_scores.max(),2),
    "Lowest Rating":round(avg_scores.min(),2)
}

# %%
insights
# Out:
# {'Top 3 aspects': {'Well versed with the subject': 7.497502497502498,
#   'Explains concepts in an understandable way': 6.081918081918082,
#   'Use of presentations': 5.942057942057942},
#  'Bottom 3 aspects': {'Course recommendation based on relevance': 5.5984015984015985,
#   'Solves doubts willingly': 5.474525474525475,
#   'Degree of difficulty of assignments': 5.430569430569431},
#  'Overall Average satisfaction': 5.92,
#  'Highest Rating': 7.5,
#  'Lowest Rating': 5.43}

# %%
pip install textblob
# Out:
# ...
#
# ...

# %%
import random
def generate_feedback(score):
    if score>=8:
        return random.choice([
            "The course was excellent and very wel framed"
            "Very beginner friendly and the course kept so engaging"
        ])
    elif score >=6:
        return random.choice([
            "The course was okay but couldve improved in few areas"
            "Few topics are very confusing and made the topic complex"
        ])
    else:
        return random.choice([
            "The course is very difficult to follow and need improvement"
            "I struggled to understand the concepts and discontinued"
        ])

# %%
from nltk.corpus import stopwords

# %%
import random
def generate_feedback(score):
    if score>=8:
        return random.choice([
            "The course was excellent and very wel framed"
            "Very beginner friendly and the course kept so engaging"
        ])
    elif score >=6:
        return random.choice([
            "The course was okay but couldve improved in few areas"
            "Few topics are very confusing and made the topic complex"
        ])
    else:
        return random.choice([
            "The course is very difficult to follow and need improvement"
            "I struggled to understand the concepts and discontinued"
        ])

# %%
df_clean['Feedback'] = df_clean['Overall_Score'].apply(generate_feedback)
print(df_clean[['Overall_Score', 'Feedback']].head())
# Out:
#    Overall_Score                                           Feedback
# 0          5.000  The course is very difficult to follow and nee...
# 1          4.875  The course is very difficult to follow and nee...
# 2          4.375  The course is very difficult to follow and nee...
# 3          5.875  The course is very difficult to follow and nee...
# 4          7.500  The course was okay but couldve improved in fe...

# %%
feedback_column = "Feedback"

for col in df.columns:
    if 'feedback' in col.lower():
        feedback_column = col
        break

if not feedback_column:
    raise ValueError("No column containing 'feedback' found in the CSV.")

# %%
import pandas as pd
from nltk.corpus import stopwords
import nltk

# Make sure stopwords are downloaded
nltk.download('stopwords')

def clean_text(text):
    if pd.isnull(text):
        return ""
    text = str(text).lower()
    # Keep only letters and spaces
    text = "".join(char for char in text if char.isalpha() or char.isspace())
    stop_words = set(stopwords.words('english'))
    text = " ".join(word for word in text.split() if word not in stop_words)
    return text

feedback_column = "Feedback"   # make sure this column exists in your dataset

df_clean['Cleaned_Feedback'] = df_clean[feedback_column].apply(clean_text)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ashwini\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %%
df_clean['Cleaned_Feedback']
# Out:
# 0       course difficult follow need improvementi stru...
# 1       course difficult follow need improvementi stru...
# 2       course difficult follow need improvementi stru...
# 3       course difficult follow need improvementi stru...
# 4       course okay couldve improved areasfew topics c...
#                               ...
# 996     course okay couldve improved areasfew topics c...
# 997     course difficult follow need improvementi stru...
# 998     course difficult follow need improvementi stru...
# 999     course difficult follow need improvementi stru...
# 1000    course difficult follow need improvementi stru...
# Name: Cleaned_Feedback, Length: 1001, dtype: object

# %%
from textblob import TextBlob

def get_sentiment(text):
    analysis = TextBlob(text)
    polarity = analysis.sentiment.polarity
    if polarity > 0:
        return 'Positive'
    elif polarity < 0:
        return 'Negative'
    else:
        return 'Neutral'

df_clean['Sentiment'] = df_clean['Cleaned_Feedback'].apply(get_sentiment)
df_clean['Polarity'] = df_clean['Cleaned_Feedback'].apply(lambda x: TextBlob(x).sentiment.polarity)

print(df_clean[['Cleaned_Feedback', 'Sentiment', 'Polarity']].head())
# Out:
#                                     Cleaned_Feedback Sentiment  Polarity
# 0  course difficult follow need improvementi stru...  Negative -0.500000
# 1  course difficult follow need improvementi stru...  Negative -0.500000
# 2  course difficult follow need improvementi stru...  Negative -0.500000
# 3  course difficult follow need improvementi stru...  Negative -0.500000
# 4  course okay couldve improved areasfew topics c...  Negative -0.033333

# %%
from textblob import TextBlob

def get_sentiment(text):
    analysis = TextBlob(text)
    polarity = analysis.sentiment.polarity
    
    if polarity > 0.1:     # positive if polarity > 0.1
        return "Positive"
    elif polarity < -0.1:  # negative if polarity < -0.1
        return "Negative"
    else:                  # between -0.1 and 0.1 = neutral
        return "Neutral"

# Apply sentiment function
df_clean['Sentiment'] = df_clean['Cleaned_Feedback'].apply(get_sentiment)

# Show counts
print(df_clean['Sentiment'].value_counts())
# Out:
# Sentiment
# Negative    533
# Neutral     456
# Positive     12
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Count sentiments (include 0 for missing)
sentiment_counts = df_clean['Sentiment'].value_counts().reindex(
    ["Positive", "Negative", "Neutral"], 
    fill_value=0
)

plt.figure(figsize=(6,4))
sentiment_counts.plot(
    kind='bar',
    color=['green','red','gray'],
    edgecolor='black'
)
plt.title('Sentiment Distribution')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS

def generate_wordcloud(text, title):
    wordcloud = WordCloud(
        width=200,
        height=150,
        background_color='white',
        stopwords=STOPWORDS
    ).generate(text)
    
    plt.figure(figsize=(10,5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.title(title, fontsize=16)
    plt.show()

# Word Cloud for all feedback
generate_wordcloud(" ".join(df_clean['Cleaned_Feedback']), "Word Cloud - All Feedback")

# Word Clouds by sentiment
generate_wordcloud(" ".join(df_clean[df_clean['Sentiment']=="Positive"]['Cleaned_Feedback']), "Positive Feedback")
generate_wordcloud(" ".join(df_clean[df_clean['Sentiment']=="Negative"]['Cleaned_Feedback']), "Negative Feedback")
generate_wordcloud(" ".join(df_clean[df_clean['Sentiment']=="Neutral"]['Cleaned_Feedback']), "Neutral Feedback")

# %%
df_clean[[feedback_column, 'Sentiment' , 'Polarity']].head(10)
# Out:
#                                             Feedback Sentiment  Polarity
# 0  The course is very difficult to follow and nee...  Negative -0.500000
# 1  The course is very difficult to follow and nee...  Negative -0.500000
# 2  The course is very difficult to follow and nee...  Negative -0.500000
# 3  The course is very difficult to follow and nee...  Negative -0.500000
# 4  The course was okay but couldve improved in fe...   Neutral -0.033333
# 5  The course is very difficult to follow and nee...  Negative -0.500000
# 6  The course is very difficult to follow and nee...  Negative -0.500000
# 7  The course was okay but couldve improved in fe...   Neutral -0.033333
# 8  The course was okay but couldve improved in fe...   Neutral -0.033333
# 9  The course is very difficult to follow and nee...  Negative -0.500000

# %%
import pandas as pd
df=pd.read_csv("student_feedback.csv")
print(df.columns.tolist())
print(df.head())
# Out:
# ['Unnamed: 0', 'Student ID', 'Well versed with the subject', 'Explains concepts in an understandable way', 'Use of presentations', 'Degree of difficulty of assignments', 'Solves doubts willingly', 'Structuring of the course', 'Provides support for students going above and beyond', 'Course recommendation based on relevance']
#    Unnamed: 0  Student ID  Well versed with the subject  \
# 0           0         340                             5
# 1           1         253                             6
# 2           2         680                             7
# 3           3         806                             9
# 4           4         632                             8
#
#    Explains concepts in an understandable way  Use of presentations  \
# 0                                           2                     7
# 1                                           5                     8
# 2                                           7                     6
# ...

# %%
df.columns=df.columns.str.strip().str.replace(' ','_').str.lower()
print(df.columns)
# Out:
# Index(['unnamed:_0', 'student_id', 'well_versed_with_the_subject',
#        'explains_concepts_in_an_understandable_way', 'use_of_presentations',
#        'degree_of_difficulty_of_assignments', 'solves_doubts_willingly',
#        'structuring_of_the_course',
#        'provides_support_for_students_going_above_and_beyond',
#        'course_recommendation_based_on_relevance'],
#       dtype='object')

# %% [markdown]
# 📌Conclusion:
#        The dataset analysis indicates that the majority of students provided positive feedback and reported high overall satisfaction.
# Neutral and negative feedback were comparatively lower, suggesting that while there are areas for improvement, overall student sentiment is favorable.
# Correlation analysis further shows that higher feedback scores are strongly associated with higher overall satisfaction, reinforcing the reliability of the collected feedback in measuring course effectiveness.
